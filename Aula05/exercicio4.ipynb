# %%
pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-Learn
# Out:
# ...
#
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np # cria a biblioteca numpy
from sklearn.linear_model import LinearRegression # da biblioteca
# Skylearn importa o modelo de regressão linear
import matplotlib.pyplot as plt

# %%
# Dados de treinamento
Renda = np.array([1200,5000,8000,10000,30000]). reshape (-1, 1)#Temperatura do forno
Gastos= np.array([750,1500,4000,6000,18000]) # quantidade de calor
#cria e treiba o modelo de regressão linear
modelo = LinearRegression() #cria uma variavel chamada modelo
modelo.fit(Renda, Gastos) # cria um modelo com base nos dados de entrada
# Out:
# LinearRegression()

# %%
# Dados de teste
GastosClientes= np.array([1400, 3000, 4580,5500,1800, 20000, 31000]).reshape(-1, 1)  
# Fazer previsões com base na temperatura
RendaSalario_Modelo= modelo.predict(GastosClientes)

# %%
# Imprimir as previsões
for i in range(len(GastosClientes)): # laço de repetição para exibir os dados
    # de saida
    print(f"Area: {GastosClientes[i][0]} - Nível previsto: {RendaSalario_Modelo[i]} temperatura")
# gráfico de pontos - scatter
plt.scatter(GastosClientes, RendaSalario_Modelo, color='blue', label='Dados de Treinamento') 
# gráfico de linhas 
plt.plot(Renda,Gastos, color  = 'red',label='Dados de teste')
plt.xlabel('Gastos Previsto')
plt.ylabel('Renda ')
plt.title('Previsão sos gastos dos clientes com base no salário.')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Area: 1400 - Nível previsto: 184.35034359887982 temperatura
# Area: 3000 - Nível previsto: 1178.5282514634764 temperatura
# Area: 4580 - Nível previsto: 2160.2789354797656 temperatura
# Area: 5500 - Nível previsto: 2731.9312325019087 temperatura
# Area: 1800 - Nível previsto: 432.894820565029 temperatura
# Area: 20000 - Nível previsto: 11741.668522524815 temperatura
# Area: 31000 - Nível previsto: 18576.641639093916 temperatura
