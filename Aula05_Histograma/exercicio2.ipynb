# %%
#2) Criar um script para prever a temperatura de um forno a partir da quantidade de
#calor fornecida.
#Q = [100,200,300,400,500,600,700]
#T = [30,35,40,45,60,100,150]

# %%
pip install pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-Learn
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import numpy as np # cria a biblioteca numpy
from sklearn.linear_model import LinearRegression # da biblioteca
# Skylearn importa o modelo de regressão linear
import matplotlib.pyplot as plt

# %%
# Dados de treinamento
temperatura = np.array([30,35,40,45,60,100,150]). reshape (-1, 1)#Temperatura do forno
                       
quantidadeCalor = np.array([100,200,300,400,500,600,700]) # quantidade de calor
#cria e treiba o modelo de regressão linear
modelo = LinearRegression() #cria uma variavel chamada modelo
modelo.fit(temperatura, quantidadeCalor) # cria um modelo com base nos dados de entrada
# Out:
# LinearRegression()

# %%
# Dados de teste
calorTemperatura = np.array([5, 20, 7,30,50, 40, 70]).reshape(-1, 1)  # temperatura
# Fazer previsões com base na temperatura
nivel_modelo= modelo.predict(calorTemperatura)

# %%
# Imprimir as previsões
for i in range(len(calorTemperatura)): # laço de repetição para exibir os dados
    # de saida
    print(f"Calor: {calorTemperatura[i][0]} - Nível previsto: {nivel_modelo[i]} temperatura")
# gráfico de pontos - scatter
plt.scatter(calorTemperatura, nivel_modelo, color='blue', label='Dados de Treinamento') 
# gráfico de linhas 
plt.plot(temperatura,quantidadeCalor, color  = 'red',label='Dados de teste')
plt.xlabel('Temperatura')
plt.ylabel('Quantidade de calor ')
plt.title('Relação entre Temperatura e Quantidade de calor')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Calor: 5 - Nível previsto: 133.55869698832203 temperatura
# Calor: 20 - Nível previsto: 199.3853718500307 temperatura
# Calor: 7 - Nível previsto: 142.3355869698832 temperatura
# Calor: 30 - Nível previsto: 243.2698217578365 temperatura
# Calor: 50 - Nível previsto: 331.03872157344813 temperatura
# Calor: 40 - Nível previsto: 287.1542716656423 temperatura
# Calor: 70 - Nível previsto: 418.80762138905965 temperatura
